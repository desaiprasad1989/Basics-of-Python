# %% [markdown]
# ## Python Programming Assignment

# %% [markdown]
# ### Exercise 1: Prime Numbers
# #####
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
num = int(input("Enter a Number : "))

flag = False

if num == 0 or num == 1:
    print(f" {num} is not a Prime Number.")
elif num > 1:
    for i in range(2, num):
        if (num % i) == 0:
            flag = True
            break

    if flag:
        print(f"{num} is not a Prime Number.")
    else:
        print(f"{num} is a Prime Numner")
# Out:
# Enter a Number :  0
#  0 is not a Prime Number.

# %% [markdown]
# ### Exercise 2: Product of Random Numbers
# ##### Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message

# %%
import random

num1 = random.randint(2,10)
num2 = random.randint(2,10)

product = num1 * num2

print("The two numbers are generated between the range 2 to 10. Enter the product for the random numbers to check whether your suggested products is correct or not")
user_product = int(input("Enter the product for the random numbers :"))

if product == user_product:
    print(f"Random generated numbers are {num1} and {num2}.")
    print(f"Congrats!!! Your guess is correct. Product of numbers is {product} and you entered product is {user_product}.")
else:
    print(f"Random generated numbers are {num1} and {num2}.")
    print(f"Sorry!!! Your guess is not correct. Product of numbers is {product} and you entered product is {user_product}.")
# Out:
# The two numbers are generated between the range 2 to 10. Enter the product for the random numbers to check whether your suggested products is correct or not
# Enter the product for the random numbers : 34
# Random generated numbers are 8 and 6.
# Sorry!!! Your guess is not correct. Product of numbers is 48 and you entered product is 34.

# %% [markdown]
# ### Exercise 3: Squares of Even/Odd Numbers
# #####
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
numbers = list(range(100,200))

squared_even = []
squared_odd = []

for num in numbers:
    if num % 2 == 0:
        squared_even.append(num ** 2)
    else:
        squared_odd.append(num ** 2)

inp = int(input("Enter your choice (1 for Even, 0 for Odd): "))

if inp == 1:
    print(f"You have entered {inp} to check all squared even numbers : {squared_even}")
elif inp == 0:
    print(f"You have entered {inp} to check all squared odd numbers : {squared_odd}")
else:
    print("Please enter valid input")
# Out:
# Enter your choice (1 for Even, 0 for Odd):  0
# You have entered 0 to check all squared odd numbers : [10201, 10609, 11025, 11449, 11881, 12321, 12769, 13225, 13689, 14161, 14641, 15129, 15625, 16129, 16641, 17161, 17689, 18225, 18769, 19321, 19881, 20449, 21025, 21609, 22201, 22801, 23409, 24025, 24649, 25281, 25921, 26569, 27225, 27889, 28561, 29241, 29929, 30625, 31329, 32041, 32761, 33489, 34225, 34969, 35721, 36481, 37249, 38025, 38809, 39601]

# %% [markdown]
# ### Exercise 4: Word counter
# ##### write a program to count the number of words in a given text.
# ##### example:
# ##### input_text = "This is a sample text. This text will be used to demonstrate the word counter."
# ##### Expected output:
# ##### 'This': 2
# ##### 'is': 1
# ##### 'a': 1
# ##### 'sample': 1
# ##### 'text.': 1

# %%
input_text = "This is a sample text. This text will be used to demonstrate the word counter."

word = 1

for i in input_text.split():
    print(f"'{i}' : {len(i)} Chars")

for i in input_text:    
    if (i == ' '):
        word=word+1
    
print(f"Total number of words in string : {word}")
# Out:
# 'This' : 4 Chars
# 'is' : 2 Chars
# 'a' : 1 Chars
# 'sample' : 6 Chars
# 'text.' : 5 Chars
# 'This' : 4 Chars
# 'text' : 4 Chars
# 'will' : 4 Chars
# 'be' : 2 Chars
# 'used' : 4 Chars
# 'to' : 2 Chars
# 'demonstrate' : 11 Chars
# 'the' : 3 Chars
# 'word' : 4 Chars
# 'counter.' : 8 Chars
# Total number of words in string : 15

# %% [markdown]
# ### Exercise 5: Check for Palindrome
# ##### Write a Python function called is_palindrome that takes a string as input and returns True if the string is a palindrome, and False otherwise. A palindrome is a word, phrase, number, or other sequence of characters that reads the same forward and backward, ignoring spaces, punctuation, and capitalization.
# ##### Example:
# ##### Input: "racecar"
# ##### Expected Output: True

# %%
def is_palindrome(input_string):
    new_string = ""
    reverse_string = ""
    for letter in input_string.lower():
        if letter != " ":
            new_string = new_string + letter
            reverse_string = letter + reverse_string
    
    if new_string == reverse_string:
        return True
    return False

# %%
print(is_palindrome("Never Odd or Even")) 
print(is_palindrome("racecar")) 
print(is_palindrome("123267"))
# Out:
# True
# True
# False
